# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples=1000, n_features=10, noise=0.1, random_state = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train.shape, X_test.shape
# Out:
# ((800, 10), (200, 10))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
linear_reg = LinearRegression()
dt_reg = DecisionTreeRegressor()
svr_reg = SVR(kernel = 'linear')

# %%
from sklearn.ensemble import VotingRegressor
ensembles_reg = VotingRegressor(estimators=[('linear_reg', linear_reg), ('decision_tree_reg', dt_reg), ('support_vector_reg', svr_reg)])

# %%
ensembles_reg.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('linear_reg', LinearRegression()),
#                             ('decision_tree_reg', DecisionTreeRegressor()),
#                             ('support_vector_reg', SVR(kernel='linear'))])

# %%
y_pred = ensembles_reg.predict(X_test)
y_pred
# Out:
# array([  49.94225635,   37.08799931, -165.4724235 ,  -41.48319849,
#         503.07435753,  325.50344599,   46.31822525,  -54.52450392,
#        -106.23432287,  -72.87482846, -100.76669527,   48.29758272,
#         -82.94518234, -143.26542553, -311.55125961, -145.45365535,
#        -272.85089546, -163.33857005,  -29.35579152, -187.5724345 ,
#         -68.18178184, -136.20598004,  302.53249562, -195.6097996 ,
#          81.43984705,  191.73203423,  237.17596557,   52.89415736,
#         -66.79627324,  111.46977232,   71.57114458,  242.09955476,
#         133.77866601,  273.59571139,  121.53350892,  102.45859897,
#          46.77523303, -397.0630257 , -184.14777544, -107.75828082,
#          47.44785859, -100.667716  ,  108.20962995, -132.66115906,
#          82.36148825,   27.88364075,  178.46246678, -121.92938931,
#         160.87054753, -291.28181732,  217.70861401,  364.42615339,
#        -240.32164403,   77.88087229,  -41.05039087,  167.79305466,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9532294706271255

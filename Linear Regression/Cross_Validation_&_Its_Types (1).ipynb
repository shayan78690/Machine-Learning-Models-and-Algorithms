# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.drop("name", axis = 1, inplace = True)

# %%
df.dropna(axis = 0, inplace = True)

# %%
# convert string columns to numerical

df['origin'] = df['origin'].map({"usa" : 1, "japan" : 2, "europe" : 3})

# %%
# seperate X and y
X = df.drop('mpg', axis = 1)
y = df['mpg']

# %%
X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
# train test split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 246          4          78.0        52.0    1985          19.4          78
# 9            8         390.0       190.0    3850           8.5          70
# 146          4          90.0        75.0    2125          14.5          74
# 142          4          79.0        67.0    1963          15.5          74
# 98           6         250.0       100.0    3278          18.0          73
# ..         ...           ...         ...     ...           ...         ...
# 253          6         200.0        95.0    3155          18.2          78
# 130          4         122.0        80.0    2451          16.5          74
# 345          4          81.0        60.0    1760          16.1          81
# 58           4          97.5        80.0    2126          17.0          72
# 226          6         231.0       105.0    3425          16.9          77
#
#      origin
# 246       2
# 9         1
# 146       1
# 142       3
# ...

# %%
# multiple linear regression
from sklearn.linear_model import LinearRegression
regression_model = LinearRegression()

# %%
regression_model
# Out:
# LinearRegression()

# %%
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
y_pred_linear = regression_model.predict(X_test)

# %%
r2_linear = r2_score(y_test, y_pred_linear)
print(f"The R square of linear regression {r2_linear}")
# Out:
# The R square of linear regression 0.8414144519844085

# %%
# If you have different arrangement of data the pattern learn might be slighly different
# you have not set the random state
# you will have differernt r2_score
# whenever you do new experiment you will get the different r2_score
# then you will take the average of all r2_score

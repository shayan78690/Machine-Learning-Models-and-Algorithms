# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The "mpg" dataset, which stands for "miles per gallon". It contains information about various car models and their characteristics, such as cylinders, displacement, horsepower, weight, acceleration, model year, origin, and miles per gallon (mpg) fuel efficiency.
#
# Here's a brief explanation of each column:
#
# mpg: Miles per gallon, representing the fuel efficiency of the car. cylinders: Number of cylinders in the engine. displacement: Engine displacement, the measure of the cylinder volume swept by all of the pistons of a piston engine. horsepower: The power of the engine, typically measured in horsepower (hp). weight: Weight of the car, often measured in pounds. acceleration: Acceleration of the car from 0 to 60 miles per hour (mph) in seconds. model year: Year of manufacturing of the car model. origin: Origin of the car, represented as a categorical variable (1: USA, 2: Europe, 3: Japan). name: The name of the car model. This dataset is commonly used for regression tasks, where the goal is to predict the fuel efficiency (mpg) of a car based on its other characteristics

# %%
# 1 mile = 1.6 km
# 1 gallon = 3.7 m

# %%
df = sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.drop("name", axis = 1, inplace = True)

# %%
df # machine learning is about learning pattern from the data and here id, name are present, ml will not learn pattern from them
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70     usa
# 1            70     usa
# 2            70     usa
# 3            70     usa
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
# Data Injection or Reading the data
# EDA
# Data Preparation, Data Cleaning, Feature Engineering
# Divide Data into X and y
# Train-Test-Split
# Scaling (Optional)
# Model Training
# Model Evalutaion

# %% [markdown]
# # Data Injection and Reading

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %%
df.shape
# Out:
# (398, 8)

# %%
df.size
# Out:
# 3184

# %%
# since we have not done outlier treatment then better idea would be to replace tthe missing value with median

# %%
df['horsepower'].median()
# Out:
# 93.5

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
# origin is a object column
df['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %% [markdown]
# #Data Preparation, Data Cleaning, Feature Engineering

# %%
# since it is a categorical column
# it is compulsory to do data encoding

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()

# %%
df['origin'] = df['origin'].map({"usa" : 1, "japan" : 2, "europe" : 3})

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 25.0 KB

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# dtype: object

# %% [markdown]
# #EDA

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
df['cylinders'].value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12, 8))
plt.title("Cylinders Count")
sns.countplot(x = 'cylinders', data = df)
plt.xlabel("Cylinder")
plt.ylabel("Counts")
plt.show()

# %%
columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'model_year', 'origin']

# %%
columns[0]
# Out:
# 'mpg'

# %%
for col in columns:
  plt.figure(figsize = (12, 8))
  plt.title(col)
  sns.histplot(df[col], kde=True, color='purple')
  plt.xlabel(col)
  plt.ylabel("Density")
  plt.show()

# %% [markdown]
# # Division of Data

# %%
X = df.drop('mpg', axis = 1)
y = df['mpg']

# %%
X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((278, 7), (120, 7), (278,), (120,))

# %% [markdown]
# # Scaling

# %% [markdown]
# # Model Training

# %%
# simple linear regression model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-0.31761423,  0.02623748, -0.01827076, -0.00748775,  0.05040673,
#         0.84709514,  1.51909584])

# %%
model.intercept_
# Out:
# -23.085380742316712

# %%
for i, col_name in enumerate(X_train.columns):
  print(f"{col_name} : {model.coef_[i]}")
# Out:
# cylinders : -0.31761423027992997
# displacement : 0.02623748259907894
# horsepower : -0.018270764913124644
# weight : -0.007487750398361904
# acceleration : 0.050406734619713886
# model_year : 0.8470951427061371
# origin : 1.5190958387975042

# %%
# some of the cofficients are very very low
# It means their importance is low
# they are less contributing

# %%
# observation >> coeff are relatively smaller
# if one independent variable changes
# there will be not much difference in prediction
# this is sometimes called as smoother model

# %%
# these features might not be contributiong in model trainng

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import r2_score
y_pred_linear = model.predict(X_test)

# %%
r2_linear = r2_score(y_test, y_pred_linear)
print("The r_score of linear regression is ", r2_linear)
# Out:
# The r_score of linear regression is  0.8348001123742284

# %% [markdown]
# #Implementation of Regularised Model

# %%
from sklearn.linear_model import Ridge
ridge_model = Ridge(alpha=0.1)
# in practical implementation lambda is alpha

# %%
ridge_model
# Out:
# Ridge(alpha=0.1)

# %%
ridge_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
for i, col_name in enumerate(X_train.columns):
  print(f"{col_name} : {ridge_model.coef_[i]}")
# Out:
# cylinders : -0.31700321010067906
# displacement : 0.02621324975798342
# horsepower : -0.018263252481449534
# weight : -0.00748732605021309
# acceleration : 0.050368969474425776
# model_year : 0.8470062938903167
# origin : 1.5174528285653937

# %%
# in ridge regression coeff never becomes 0
# there are some changes

# %%
# for ridge regression evalution
y_pred_ridge = ridge_model.predict(X_test)

# %%
r2_ridge = r2_score(y_test, y_pred_ridge)

# %%
print("The r_score of ridge regression is ", r2_ridge)
# Out:
# The r_score of ridge regression is  0.8348084889168355

# %%
# there is not much change in r_score
# we don't see much variation in coeff of ridge regression as compared to linear regression

# %% [markdown]
# #Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso_model = Lasso(alpha=0.5)

# %%
lasso_model
# Out:
# Lasso(alpha=0.5)

# %%
lasso_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.5)

# %%
lasso_model.intercept_
# Out:
# -12.308676402314052

# %%
lasso_model.coef_
# Out:
# array([-0.        ,  0.0062082 , -0.01105838, -0.00698267,  0.        ,
#         0.74465495,  0.        ])

# %%
for i, col_name in enumerate(X_train.columns):
  print(f"{col_name} : {lasso_model.coef_[i]}")
# Out:
# cylinders : -0.0
# displacement : 0.006208198888300358
# horsepower : -0.011058382987169565
# weight : -0.0069826731680230885
# acceleration : 0.0
# model_year : 0.744654952003819
# origin : 0.0

# %%
# Observation >> few of the coeff have become 0
# 3 features coef is 0, lasso helps in feature selection

# %%
y_pred_lasso = lasso_model.predict(X_test)

# %%
r2_lasso = r2_score(y_test, y_pred_lasso)

# %%
print("The r_score of lasso regression is ", r2_lasso)
# Out:
# The r_score of lasso regression is  0.8277934716635555

# %%
# Observation >> Now r2_score decreased
# difference of 1 %
# still you do  not have 3 irrelevant features

# %%
# it means these 3 features are unnecessary

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model import ElasticNet
elastic_model = ElasticNet(alpha=1, l1_ratio=0.5)

# %%
elastic_model
# Out:
# ElasticNet(alpha=1)

# %%
elastic_model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=1)

# %%
elastic_model.intercept_
# Out:
# -9.87460287322661

# %%
for i, col_names in enumerate(X_train.columns):
  print(f"{col_name} : {elastic_model.coef_[i]}")
# Out:
# origin : -0.0
# origin : 0.005888869953667563
# origin : -0.012403874933570126
# origin : -0.006934550516257631
# origin : 0.0
# origin : 0.7133150744603874
# origin : 0.0

# %%
y_pred_elastic = elastic_model.predict(X_test)

# %%
r2_elastic = r2_score(y_test, y_pred_elastic)

# %%
print("The r_score of elastic regression is ", r2_elastic)
# Out:
# The r_score of elastic regression is  0.8284840073256804

# %%
# regularisation with cross validation
from sklearn.linear_model import LassoCV
lasso_cv_model = LassoCV(cv=5, verbose=2)

# %%
lasso_cv_model
# Out:
# LassoCV(cv=5, verbose=2)

# %%
lasso_cv_model.fit(X_train, y_train)
# Out:
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# ...

# %%
y_pred = lasso_cv_model.predict(X_test)
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.8082805983844751

# %%
from sklearn.linear_model import RidgeCV
ridge_cv = RidgeCV(cv=5)

# %%
ridge_cv
# Out:
# RidgeCV(cv=5)

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(cv=5)

# %%
y_pred = ridge_cv.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8354145247502054

# %%
ridge_cv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': None,
#  'store_cv_values': 'deprecated'}

# %%
from sklearn.linear_model import ElasticNetCV
elastic_cv = ElasticNetCV(cv=5)

# %%
elastic_cv
# Out:
# ElasticNetCV(cv=5)

# %%
elastic_cv.fit(X_train, y_train)
# Out:
# ElasticNetCV(cv=5)

# %%
y_pred = elastic_cv.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.792863401804916
